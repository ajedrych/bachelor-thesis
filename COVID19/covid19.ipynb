# %% [markdown]
# ### COVID-19

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
zakazenia = pd.read_excel('merged.xlsx')

# %%
zakazenia
# Out:
#                wojewodztwo    powiat_miasto liczba_przypadkow  \
# 0               CaĹ‚y kraj       CaĹ‚y kraj             10141
# 1           dolnoĹ›lÄ…skie   bolesĹ‚awiecki                62
# 2           dolnoĹ›lÄ…skie  dzierĹĽoniowski                31
# 3           dolnoĹ›lÄ…skie       gĹ‚ogowski                19
# 4           dolnoĹ›lÄ…skie        gĂłrowski                 3
# ...                    ...              ...               ...
# 183736  zachodniopomorskie          wałecki                12
# 183737  zachodniopomorskie          łobeski                15
# 183738  zachodniopomorskie         Koszalin                48
# 183739  zachodniopomorskie         Szczecin               268
# 183740  zachodniopomorskie      Świnoujście                28
#
#        liczba_na_10_tys_mieszkancow  zgony  \
# 0               1964-02-01 00:00:00  540.0
# 1               1989-06-01 00:00:00    2.0
# 2               2022-08-03 00:00:00    NaN
# ...

# %%
zakazenia.to_excel('zakazenia_all.xlsx', index=False, encoding='utf-8-sig')
