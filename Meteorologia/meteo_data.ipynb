# %%
import pandas as pd

# %%
opady = pd.read_csv("suma_opadow.csv", sep=";")
opady
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7756/1615239512.py in <module>
# ----> 1 opady = pd.read_csv("suma_opadow.csv", sep=";")
#       2 opady
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
opady1 = opady.loc[opady['250180590'] == '352200375']
opady1.to_csv("opady.csv")

# %%
temperatura = pd.read_csv("temperatura_powietrza.csv", sep=";")
temperatura
# Out:
# C:\Users\aleks\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           249190890  B00300S  2018-01-01 00:00  4,1  Unnamed: 4
# 0         249190890  B00300S  2018-01-01 00:10  4,1         NaN
# 1         249190890  B00300S  2018-01-01 00:20    4         NaN
# 2         249190890  B00300S  2018-01-01 00:30  3,8         NaN
# 3         249190890  B00300S  2018-01-01 00:40  4,6         NaN
# 4         249190890  B00300S  2018-01-01 00:50  4,4         NaN
# ...             ...      ...               ...  ...         ...
# 47195457  252150270  B00300S  2021-10-31 23:20  5,8         NaN
# 47195458  252150270  B00300S  2021-10-31 23:30  5,4         NaN
# 47195459  252150270  B00300S  2021-10-31 23:40  5,2         NaN
# 47195460  252150270  B00300S  2021-10-31 23:50  4,5         NaN
# ...

# %%
temperatura1 = temperatura.loc[temperatura['249190890'] == '352200375']
temperatura1.to_csv("opady.csv")

# %%
wilgotnosc = pd.read_csv("wilgotnosc_powietrza.csv", sep=";")
wilgotnosc
# Out:
# C:\Users\aleks\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (0,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           254140010  B00802A  2018-01-01 00:00   99  Unnamed: 4
# 0         254140010  B00802A  2018-01-01 00:10   99         NaN
# 1         254140010  B00802A  2018-01-01 00:20   99         NaN
# 2         254140010  B00802A  2018-01-01 00:30   99         NaN
# 3         254140010  B00802A  2018-01-01 00:40   99         NaN
# 4         254140010  B00802A  2018-01-01 00:50   99         NaN
# ...             ...      ...               ...  ...         ...
# 48737021  252150270  B00802A  2021-10-31 23:20   86         NaN
# 48737022  252150270  B00802A  2021-10-31 23:30   88         NaN
# 48737023  252150270  B00802A  2021-10-31 23:40   89         NaN
# 48737024  252150270  B00802A  2021-10-31 23:50   88         NaN
# ...

# %%
wilgotnosc1 = wilgotnosc.loc[wilgotnosc['254140010'] == '352200375']
wilgotnosc1.to_csv("opady.csv")
